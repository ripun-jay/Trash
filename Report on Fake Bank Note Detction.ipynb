# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("files/note.csv")

# %%
data.head(5)
# Out:
#         v1      v2      v3       v4  c
# 0  3.62160  8.6661 -2.8073 -0.44699  1
# 1  4.54590  8.1674 -2.4586 -1.46210  1
# 2  3.86600 -2.6383  1.9242  0.10645  1
# 3  3.45660  9.5228 -4.0112 -3.59440  1
# 4  0.32924 -4.4552  4.5718 -0.98880  1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      1372 non-null   float64
#  1   v2      1372 non-null   float64
#  2   v3      1372 non-null   float64
#  3   v4      1372 non-null   float64
#  4   c       1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
data.cov()
# Out:
#           v1         v2         v3        v4         c
# v1  8.081299   4.405083  -4.666323  1.653338 -1.024310
# v2  4.405083  34.445710 -19.905119 -6.490033 -1.297386
# v3 -4.666323 -19.905119  18.576359  2.887241  0.333985
# v4  1.653338  -6.490033   2.887241  4.414256 -0.024464
# c  -1.024310  -1.297386   0.333985 -0.024464  0.247112

# %%
data.corr()
# Out:
#           v1        v2        v3        v4         c
# v1  1.000000  0.264026 -0.380850  0.276817 -0.724843
# v2  0.264026  1.000000 -0.786895 -0.526321 -0.444688
# v3 -0.380850 -0.786895  1.000000  0.318841  0.155883
# v4  0.276817 -0.526321  0.318841  1.000000 -0.023424
# c  -0.724843 -0.444688  0.155883 -0.023424  1.000000

# %%
data.describe()
# Out:
#                 v1           v2           v3           v4            c
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     1.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     1.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     1.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     1.000000
# 75%       2.821475     6.814625     3.179250     0.394810     2.000000
# max       6.824800    12.951600    17.927400     2.449500     2.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data.hist(bins= 50)
plt.title("Distribution")
# Out:
# Text(0.5, 1.0, 'Distribution')

# %%
pd.plotting.scatter_matrix(data[["v1","v2","v3","v4","c"]], figsize= (20,10), c = data["c"], alpha=0.25)
# Out:
# array([[<Axes: xlabel='v1', ylabel='v1'>,
#         <Axes: xlabel='v2', ylabel='v1'>,
#         <Axes: xlabel='v3', ylabel='v1'>,
#         <Axes: xlabel='v4', ylabel='v1'>,
#         <Axes: xlabel='c', ylabel='v1'>],
#        [<Axes: xlabel='v1', ylabel='v2'>,
#         <Axes: xlabel='v2', ylabel='v2'>,
#         <Axes: xlabel='v3', ylabel='v2'>,
#         <Axes: xlabel='v4', ylabel='v2'>,
#         <Axes: xlabel='c', ylabel='v2'>],
#        [<Axes: xlabel='v1', ylabel='v3'>,
#         <Axes: xlabel='v2', ylabel='v3'>,
#         <Axes: xlabel='v3', ylabel='v3'>,
#         <Axes: xlabel='v4', ylabel='v3'>,
#         <Axes: xlabel='c', ylabel='v3'>],
#        [<Axes: xlabel='v1', ylabel='v4'>,
#         <Axes: xlabel='v2', ylabel='v4'>,
#         <Axes: xlabel='v3', ylabel='v4'>,
#         <Axes: xlabel='v4', ylabel='v4'>,
#         <Axes: xlabel='c', ylabel='v4'>],
#        [<Axes: xlabel='v1', ylabel='c'>, <Axes: xlabel='v2', ylabel='c'>,
# ...

# %%
def colors(value):
    if value == 1:
        return "green"
    else:
        return "red"

# %%
plt.scatter(data["v1"], data["v2"], c= data["c"], alpha=0.25)
plt.xlabel("v1")
plt.ylabel("v2")
plt.title("Fake Note")
# Out:
# Text(0.5, 1.0, 'Fake Note')

# %%
plt.scatter(data["v1"], data["v3"], c= data["c"], alpha=0.25)
plt.xlabel("v1")
plt.ylabel("v3")
plt.title("Fake Note")
# Out:
# Text(0.5, 1.0, 'Fake Note')

# %%
plt.scatter(data["v1"], data["v4"], c= data["c"], alpha=0.25)

# %%
plt.scatter(data["v2"], data["v3"], c= data["c"], alpha=0.25)

# %%
plt.scatter(data["v2"], data["v4"], c= data["c"], alpha=0.25)

# %%
plt.scatter(data["v3"], data["v4"], c= data["c"], alpha=0.25)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(data["v1"], data["v2"], data["v3"], c= data["c"], alpha=0.25,)
ax.set_xlabel("v1")
ax.set_ylabel("v2")
ax.set_zlabel("v3")
# Out:
# Text(0.5, 0, 'v3')

# %%
ax.scatter(data["v1"], data["v2"], data["v4"], c= data["c"], alpha=0.25)

# %%
data["v5"] = data["v1"]*data["v2"]

# %%
plt.scatter(data["v3"], data["v5"], c= data["c"], alpha=0.25)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(data["v4"], data["v5"], data["v3"], c= data["c"], alpha=0.25,)

# %%
data.corr()
# Out:
#           v1        v2        v3        v4         c        v5
# v1  1.000000  0.264026 -0.380850  0.276817 -0.724843  0.355636
# v2  0.264026  1.000000 -0.786895 -0.526321 -0.444688 -0.071334
# v3 -0.380850 -0.786895  1.000000  0.318841  0.155883  0.069704
# v4  0.276817 -0.526321  0.318841  1.000000 -0.023424  0.129617
# c  -0.724843 -0.444688  0.155883 -0.023424  1.000000 -0.126258
# v5  0.355636 -0.071334  0.069704  0.129617 -0.126258  1.000000

# %%
data["v12"] = data["v1"] + data["v2"]
data["v33"] = (data["v2"]*0.8)+(data["v1"]*0.4)

# %%
plt.scatter(data["v33"], data["v12"], c= data["c"], alpha=0.25)

# %%
plt.scatter(data["v4"], data["c"], c= data["c"], alpha=0.25)

# %%
np_data = np.column_stack((data["v1"], data["v2"]))
np_data
# Out:
# array([[  3.6216 ,   8.6661 ],
#        [  4.5459 ,   8.1674 ],
#        [  3.866  ,  -2.6383 ],
#        ...,
#        [ -3.7503 , -13.4586 ],
#        [ -3.5637 ,  -8.3827 ],
#        [ -2.5419 ,  -0.65804]])

# %%
data_mean = np.mean(np_data, 0)
data_mean
# Out:
# array([0.43373526, 1.92235312])

# %%
data_std = np.std(np_data, 0)
data_std
# Out:
# array([2.84172641, 5.86690749])

# %%
#lokking at K-mean cluster
from sklearn.cluster import KMeans
k_points = KMeans(n_clusters = 10).fit(np_data)
# Out:
# C:\python10\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
k_points.cluster_centers_
# Out:
# array([[  2.92471947,  -4.01921136],
#        [  2.09706445,   6.14558378],
#        [ -1.54742178,   2.84272258],
#        [ -3.34382195, -12.23202195],
#        [ -2.25752565,  -6.91319116],
#        [ -1.04838888,  -0.41876149],
#        [  3.08429312,   1.67077149],
#        [ -5.53512391,   7.48570652],
#        [  3.76751314,   9.38657445],
#        [ -0.65771567,   9.99103565]])

# %%
k_mean_points = k_points.cluster_centers_
#plotting mean point of data
plt.text(data_mean[0], data_mean[1], "Mean", c="red", alpha=1, )
plt.scatter(data_mean[0], data_mean[1], s = 100, c="red", alpha=0.8, )
plt.text(data_std[0], data_std[1], "STD", c="Black", alpha=1, )
plt.scatter(data_std[0], data_std[1], s = 100, c="Black", alpha=1, )

plt.scatter(data["v1"], data["v2"], c= data["c"], alpha= 0.25)
plt.scatter(k_mean_points[:,0],k_mean_points[:,1], s = 2000, alpha=0.30, c= "green")

plt.xlabel("V1")
plt.xlabel("V2")


plt.show()
